# %%
import seabreeze
seabreeze.use('pyseabreeze')
from seabreeze.spectrometers import list_devices, Spectrometer
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import savetxt
from scipy import interpolate
from scipy.signal import find_peaks
from scipy.signal import savgol_filter
# Out:
# C:\Users\robin\AppData\Local\Temp\ipykernel_20376\1042698785.py:2: UserWarning: seabreeze.use has to be called before importing seabreeze.spectrometers
#   seabreeze.use('pyseabreeze')

# %%
spec = Spectrometer.from_first_available()

# %%
spec.integration_time_micros(30000) # Manually select an integration time (trial and error)

# %%
def scan_to_average(scans):
    intensities = []
    for i in np.arange(scans+1):
        intensities.append(spec.intensities())
        
        return intensities
    
scans = 1000
    
spectra = np.mean(scan_to_average(scans), axis = 0)[50::5]

# %%
wavelengths = spec.wavelengths()[50::5]

# %%
spec.close()

# %%
spectra_smooth = savgol_filter(spectra, 50, 3)

# %%
int(wavelengths[spectra_smooth.argmax(axis=0)])
# Out:
# 633

# %%
plt.plot(wavelengths, (spectra_smooth - np.amin(spectra_smooth))/np.amax(spectra_smooth - np.amin(spectra_smooth)), label = 'New Ring LED')

plt.ylim(0, 1)
plt.grid()
plt.ylabel('Intensity\n', fontsize = 14)
plt.xlabel('\nWavelength', fontsize = 14)
plt.legend()
plt.show()

# %%
# plt.plot(wavelengths, spectra__)
